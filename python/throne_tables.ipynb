# %%
# scraping the list of episodes and the directors
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://en.wikipedia.org/w/index.php' + \
    '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_content  = r.text

soup = BeautifulSoup(html_content, 'html.parser')

# %%
# use a list to store the episodes
episodes = []
ep_table = soup.find_all('table', class_= 'wikiepisodetable')

# %%
for table in ep_table:
    headers = []
    rows = table.find_all('tr') # fetch the rows
    
    # start by fething header cells from first row to determine field names
    for header in table.find('tr').find_all('th'):
        headers.append(header.text)
        
    # then go throu' all rows except the first
    for row in table.find_all('tr')[1: ]:
        values = []
        
        #now get the column cells, the first being inside a th-tag
        for col in row.find_all(['th', 'td']):
            values.append(col.text)
            
            if values:
                episode_dict = {headers[i]: values[i] for i in range(len(values))}
                episodes.append(episode_dict)
            
for episode in episodes:
    print(episode)
# Out:
# {'No.overall': '10'}
# {'No.overall': '10', 'No. inseason': '10'}
# {'No.overall': '10', 'No. inseason': '10', 'Title': '"Fire and Blood"'}
# {'No.overall': '10', 'No. inseason': '10', 'Title': '"Fire and Blood"', 'Directed by': 'Alan Taylor'}
# {'No.overall': '10', 'No. inseason': '10', 'Title': '"Fire and Blood"', 'Directed by': 'Alan Taylor', 'Written by': 'David Benioff & D. B. Weiss'}
# {'No.overall': '10', 'No. inseason': '10', 'Title': '"Fire and Blood"', 'Directed by': 'Alan Taylor', 'Written by': 'David Benioff & D. B. Weiss', 'Original air date\u200a[20]': 'June\xa019,\xa02011\xa0(2011-06-19)'}
# {'No.overall': '10', 'No. inseason': '10', 'Title': '"Fire and Blood"', 'Directed by': 'Alan Taylor', 'Written by': 'David Benioff & D. B. Weiss', 'Original air date\u200a[20]': 'June\xa019,\xa02011\xa0(2011-06-19)', 'U.S. viewers(millions)': '3.04[30]'}
# {'No.overall': '20'}
# {'No.overall': '20', 'No. inseason': '10'}
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
 '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')
# We'll use a list to store our episode list
episodes = []
ep_tables = html_soup.find_all('table', class_='wikiepisodetable')
for table in ep_tables:
    headers = []
    rows = table.find_all('tr')
    # Start by fetching the header cells from the first row to determine
    # the field names
    for header in table.find('tr').find_all('th'):
        headers.append(header.text)
    # Then go through all the rows except the first one
    for row in table.find_all('tr')[1:]:
        values = []
        # And get the column cells, the first one being inside a th-tag
        for col in row.find_all(['th','td']):
            values.append(col.text)
            if values:
                episode_dict = {headers[i]: values[i] for i in
                range(len(values))}
                episodes.append(episode_dict)
        # Show the results
for episode in episodes:
    print(episode)
# Out:
# {'No.overall': '1'}
# {'No.overall': '1', 'No. inseason': '1'}
# {'No.overall': '1', 'No. inseason': '1', 'Title': '"Winter Is Coming"'}
# {'No.overall': '1', 'No. inseason': '1', 'Title': '"Winter Is Coming"', 'Directed by': 'Tim Van Patten'}
# {'No.overall': '1', 'No. inseason': '1', 'Title': '"Winter Is Coming"', 'Directed by': 'Tim Van Patten', 'Written by': 'David Benioff & D. B. Weiss'}
# {'No.overall': '1', 'No. inseason': '1', 'Title': '"Winter Is Coming"', 'Directed by': 'Tim Van Patten', 'Written by': 'David Benioff & D. B. Weiss', 'Original air date\u200a[20]': 'April\xa017,\xa02011\xa0(2011-04-17)'}
# {'No.overall': '1', 'No. inseason': '1', 'Title': '"Winter Is Coming"', 'Directed by': 'Tim Van Patten', 'Written by': 'David Benioff & D. B. Weiss', 'Original air date\u200a[20]': 'April\xa017,\xa02011\xa0(2011-04-17)', 'U.S. viewers(millions)': '2.22[21]'}
# {'No.overall': '2'}
# {'No.overall': '2', 'No. inseason': '2'}
# ...
